# %%
#!/usr/bin/env python
#-*- encoding: utf-8 -*-

import requests
import time
import re
from lxml import etree
import pandas as pd

def is_all_chinese(strs):
    for _char in strs:
        if not '\u4e00' <= _char <= '\u9fa5':
            return False
    return True

def getList():
    start_url = 'https://book.douban.com/tag/青春?&type=T&start={}'
    i = 0
    infoList = []
    print(0)
    while i < 6: 
        url = start_url.format(i*20)
        kv = {'User-Agent': 'Mozilla/5.0'} 
        r = requests.get(url,headers=kv) 
        selector = etree.HTML(r.text)
        i += 1
        informations = selector.xpath('.//ul[@class="subject-list"]/li')
        
        for inf in informations: 
            info_bookname = inf.xpath('normalize-space(.//div[@class="info"]/h2/a/@title)')
            info_str = inf.xpath('normalize-space(.//div[@class="pub"]/text())')#[0].replaceAll("\r|\n", "")
            info_author = ''
            strlist = info_str.split('/')
            k = 0
            index = 0
            while k < len(strlist):
                if("出版" in strlist[k]):
                    index = k
                    break
                k += 1
            if(k == len(strlist)):
                info_publisher = '***'
                s=0
                index1 = 0
                while s < len(strlist):
                    if("." in strlist[s]):
                        info_price = strlist[s]
                        #index1 = s
                        index = s-1
                        break
                    s += 1
                if(s == len(strlist)):
                    info_price = strlist[len(strlist)-1]
                    index = len(strlist)-2
            else:
                info_publisher = strlist[index]#.replaceAll("\r|\n", "")
                info_price = strlist[index+2]#.replace('.','')#.replaceAll("\r|\n", "")
            j = 0
            while j < index:
                info_author += strlist[j]
                j += 1
                
            if("元" not in info_price):
                info_price = info_price+"元" 
            info_score = inf.xpath('normalize-space(.//span[@class="rating_nums"]/text())')#[0].replaceAll("\r|\n", "")
            info_commentsnum = inf.xpath('normalize-space(.//span[@class="pl"]/text())')#[0].replaceAll("\r|\n", "")            
            if(is_all_chinese(info_bookname)):
                infoList.append([info_bookname,info_author,info_publisher,info_price,info_score,info_commentsnum])
        time.sleep(10)
    return infoList


def listToCsv(list):
    df = pd.DataFrame(list,columns=['书名','作者','出版社','售价','豆瓣评分','评论数量'])
    file = open("1.csv", "w", encoding='utf-8')
    df.to_csv(file, line_terminator="\n", index=False)
    file.close()
    print(df)
    return list
 
def main():
    List = getList() 
    listToCsv(List)
 
 
if __name__=='__main__': 
	main()
# Out:
# 0
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-9-60071f4ca48d> in <module>
#      85
#      86 if __name__=='__main__':
# ---> 87         main()
#
# <ipython-input-9-60071f4ca48d> in main()
#      81 def main():
#      82     List = getList()
# ---> 83     listToCsv(List)
#      84
#      85
#
# <ipython-input-9-60071f4ca48d> in listToCsv(list)
#      73 def listToCsv(list):
#      74     df = pd.DataFrame(list,columns=['书名','作者','出版社','售价','豆瓣评分','评论数量'])
# ---> 75     file = open("1.csv", "w", encoding='utf-8')
#      76     df.to_csv(file, line_terminator="\n", index=False)
#      77     file.close()
#
# PermissionError: [Errno 13] Permission denied: '1.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import json
from urllib.request import urlopen, quote
import requests
import csv
import re, pandas as pd
from sklearn.preprocessing import StandardScaler
#import warnings
#warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/DELL/1.csv")
df
# Out:
#             书名                    作者         出版社       售价  豆瓣评分         评论数量
# 0           撒野                   巫哲    北京联合出版公司    45.00元   8.6   (29981人评价)
# 1      梦里花落知多少                  郭敬明     春风文艺出版社    20.00元   7.1  (166270人评价)
# 2        挪威的森林        [日] 村上春树  林少华     上海译文出版社    18.80元   8.0  (322683人评价)
# 3      麦田里的守望者  [美国] J. D. 塞林格  孙仲旭       译林出版社    28.00元   8.1   (65185人评价)
# 4   那些回不去的年少时光                   桐华     江苏文艺出版社    23.80元   8.4   (50640人评价)
# ..         ...                   ...         ...      ...   ...          ...
# 84  陪安东尼度过漫长岁月                  安东尼     长江文艺出版社    18.00元   8.3   (64622人评价)
# 85      像少年啦飞驰                   韩寒       作家出版社    16.00元   7.3   (40419人评价)
# 86          西决                   笛安     长江文艺出版社    22.80元   7.9   (56442人评价)
# 87        血色浪漫                   都梁     人民文学出版社    40.00元   8.9    (3296人评价)
# 88        狼的诱惑              可爱淘  黄黉     世界知识出版社     20.0元   6.8   (14946人评价)
#
# [89 rows x 6 columns]

# %%
publisher = df[(True^df['出版社'].isin([0]))]

# %%
publisher['value'] = 1#添加计数器
publisher
# Out:
#             书名                    作者         出版社       售价  豆瓣评分         评论数量  \
# 0           撒野                   巫哲    北京联合出版公司    45.00元   8.6   (29981人评价)
# 1      梦里花落知多少                  郭敬明     春风文艺出版社    20.00元   7.1  (166270人评价)
# 2        挪威的森林        [日] 村上春树  林少华     上海译文出版社    18.80元   8.0  (322683人评价)
# 3      麦田里的守望者  [美国] J. D. 塞林格  孙仲旭       译林出版社    28.00元   8.1   (65185人评价)
# 4   那些回不去的年少时光                   桐华     江苏文艺出版社    23.80元   8.4   (50640人评价)
# ..         ...                   ...         ...      ...   ...          ...
# 84  陪安东尼度过漫长岁月                  安东尼     长江文艺出版社    18.00元   8.3   (64622人评价)
# 85      像少年啦飞驰                   韩寒       作家出版社    16.00元   7.3   (40419人评价)
# 86          西决                   笛安     长江文艺出版社    22.80元   7.9   (56442人评价)
# 87        血色浪漫                   都梁     人民文学出版社    40.00元   8.9    (3296人评价)
# 88        狼的诱惑              可爱淘  黄黉     世界知识出版社     20.0元   6.8   (14946人评价)
#
#     value
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 84      1
# 85      1
# 86      1
# 87      1
# 88      1
#
# [89 rows x 7 columns]

# %%
df_publisher = publisher[ ['出版社','value'] ].groupby(['出版社']).sum()#按照出版社进行分组，得到不同出版社的图书数量
df_pbler=df_publisher.sort_values(by=['value'],ascending=False)
df_pbler
# Out:
#                  value
# 出版社
#  上海译文出版社             9
#  长江文艺出版社             6
#  北京十月文艺出版社           4
#  春风文艺出版社             4
#  百花洲文艺出版社            4
#  江苏文艺出版社             4
#  江苏凤凰文艺出版社           4
# ***                  3
#  南海出版公司              3
#  朝华出版社               3
#  人民文学出版社             3
#  作家出版社               3
#  天津人民出版社             3
#  湖南文艺出版社             3
#  译林出版社               3
#  青岛出版社               3
#  新世界出版社              2
#  广西师范大学出版社           2
#  万卷出版公司              2
#  世界知识出版社             2
#  二十一世纪出版社            2
#  上海人民出版社             1
#  沈阳出版社               1
#  中国友谊出版公司            1
#  中国电影出版社             1
#  花山文艺出版社             1
#  自行出版                1
#  中国青年出版社             1
#  云南美术出版社             1
#  后浪丨中国友谊出版公司         1
#  北京燕山出版社             1
#  杭州出版社               1
#  北京联合出版公司            1
#  北京联合出版公司·磨铁图书       1
#  新星出版社               1
#  华文出版社               1
#  印刷工业出版社             1
#  外语教学与研究出版社          1

# %%
df.sort_values(by=['豆瓣评分'],ascending=False)
# Out:
#            书名                作者            出版社           售价  豆瓣评分         评论数量
# 18       少年凯歌              陈凯歌        人民文学出版社        10.00元   9.2    (5724人评价)
# 64    吞噬时间的恋人              王宇昆        天津人民出版社        42.00元   9.1      (23人评价)
# 26       绿毛水怪              王小波      北京十月文艺出版社        39.00元   9.1    (5834人评价)
# 17       怦然心动  文德琳·范·德拉安南  陈常歌       百花洲文艺出版社        42.80元   9.1    (3865人评价)
# 16      平凡的世界               路遥      北京十月文艺出版社        99.00元   9.1   (17531人评价)
# ..        ...               ...            ...          ...   ...          ...
# 53    疯犬少年的天空              里则林             ***        36.8元   6.3     (241人评价)
# 69   突然好想大哭一场              黄伟康    后浪丨中国友谊出版公司        45.00元   6.2     (115人评价)
# 24     悲伤逆流成河              郭敬明        长江文艺出版社        24.00元   6.2  (101896人评价)
# 80  致我们暖暖的小时光              赵乾乾      江苏凤凰文艺出版社        29.80元   5.9    (2280人评价)
# 73  我与世界只差一个你              张皓宸        天津人民出版社    CNY 36.00元   5.8    (8227人评价)
#
# [89 rows x 6 columns]

# %%
df_s=df.sort_values(by=['豆瓣评分'],ascending=False)
df_ss=df_s.iloc[0:20]#评分前20的书籍信息
df_ss.to_csv('评分前20的书籍信息.csv')
df_ss
# Out:
#            书名                  作者           出版社         售价  豆瓣评分         评论数量
# 18       少年凯歌                陈凯歌       人民文学出版社      10.00元   9.2    (5724人评价)
# 64    吞噬时间的恋人                王宇昆       天津人民出版社      42.00元   9.1      (23人评价)
# 26       绿毛水怪                王小波     北京十月文艺出版社      39.00元   9.1    (5834人评价)
# 17       怦然心动    文德琳·范·德拉安南  陈常歌      百花洲文艺出版社      42.80元   9.1    (3865人评价)
# 16      平凡的世界                 路遥     北京十月文艺出版社      99.00元   9.1   (17531人评价)
# 8        强风吹拂  三浦紫苑  林佩瑾、李建铨、杨正敏     广西师范大学出版社      39.00元   9.0   (12826人评价)
# 45         情书          岩井俊二  穆晓芳        南海出版公司      45.00元   8.9    (5098人评价)
# 87       血色浪漫                 都梁       人民文学出版社      40.00元   8.9    (3296人评价)
# 50         潮骚      [日] 三岛由纪夫  张舟     北京十月文艺出版社         45元   8.8    (1956人评价)
# 65       白日事故          高台樹色  留守番            ***   NTD 780元   8.8    (1379人评价)
# 9        夏日终曲   [美] 安德烈·艾席蒙  吴妍蓉    外语教学与研究出版社      39.90元   8.8   (16509人评价)
# 15      雨季不再来                 三毛     北京十月文艺出版社      28.00元   8.7   (42955人评价)
# 7       最好的我们               八月长安       湖南文艺出版社         55元   8.7   (59187人评价)
# 34        小先生                咬春饼         青岛出版社      65.00元   8.6     (930人评价)
# 32  请以你的名字呼唤我        安德烈·艾席蒙  权景      中国友谊出版公司      29.80元   8.6    (9939人评价)
# 0          撒野                 巫哲      北京联合出版公司      45.00元   8.6   (29981人评价)
# 6          情书      [日] 岩井俊二  穆晓芳       天津人民出版社      18.00元   8.6   (89576人评价)
# 11      挪威的森林       [日]村上春树  林少华       上海译文出版社      38.00元   8.6    (8971人评价)
# 27      横道世之介      [日] 吉田修一  林雅惠       上海人民出版社      55.00元   8.5    (3669人评价)
# 5       挪威的森林      [日] 村上春树  林少华       上海译文出版社      23.00元   8.5  (108127人评价)

# %%
df_price=df.sort_values(by=['售价'],ascending=True)
df_pp=df_price.iloc[0:20]#售价最低前20的书籍信息
df_pp.to_csv('售价最低前20的书籍信息.csv')
df_pp
# Out:
#             书名                 作者         出版社       售价  豆瓣评分         评论数量
# 18        少年凯歌               陈凯歌     人民文学出版社    10.00元   9.2    (5724人评价)
# 25        且听风吟     [日] 村上春树  林少华     上海译文出版社    11.80元   7.8   (58976人评价)
# 76          潮骚     （日）三岛由纪夫  唐月梅     上海译文出版社    15.00元   8.2   (10976人评价)
# 13       何以笙箫默                顾漫       朝华出版社    15.00元   7.8  (139636人评价)
# 31     一个人的好天气     [日] 青山七惠  竺家荣     上海译文出版社    15.00元   7.6   (84060人评价)
# 21        动物凶猛                王朔     中国电影出版社    15.50元   8.3   (29478人评价)
# 85      像少年啦飞驰                韩寒       作家出版社    16.00元   7.3   (40419人评价)
# 81        八月未央              安妮宝贝       作家出版社    16.00元   7.5   (51638人评价)
# 48         三重门     韩寒  NONE、NONE       作家出版社    16.00元   7.4  (109085人评价)
# 43          过门            priest          ***   16.90元   8.4    (4557人评价)
# 33       七月与安生   安妮宝贝 原著、鬼鬼 改编绘画       杭州出版社    17.50元   7.5   (14976人评价)
# 44     麦田里的守望者  [美] J.D.塞林格  施咸荣       译林出版社    18.00元   7.8    (9158人评价)
# 6           情书     [日] 岩井俊二  穆晓芳     天津人民出版社    18.00元   8.6   (89576人评价)
# 84  陪安东尼度过漫长岁月               安东尼     长江文艺出版社    18.00元   8.3   (64622人评价)
# 57    夏有乔木雅望天堂                籽月     春风文艺出版社    18.00元   6.6    (8042人评价)
# 2        挪威的森林     [日] 村上春树  林少华     上海译文出版社    18.80元   8.0  (322683人评价)
# 20       那小子真帅       [韩] 可爱淘  黄黉     世界知识出版社    18.80元   6.5   (22763人评价)
# 66        一座城池                韩寒    二十一世纪出版社    19.90元   7.4   (59618人评价)
# 40         三重门                韩寒    二十一世纪出版社    19.90元   7.6   (13994人评价)
# 54        泡沫之夏               明晓溪      新世界出版社    20.00元   6.8   (47750人评价)

# %%
author = df[(True^df['作者'].isin([0]))]
author['aut_num'] = 1#添加计数器
author
# Out:
#             书名                    作者         出版社       售价  豆瓣评分         评论数量  \
# 0           撒野                   巫哲    北京联合出版公司    45.00元   8.6   (29981人评价)
# 1      梦里花落知多少                  郭敬明     春风文艺出版社    20.00元   7.1  (166270人评价)
# 2        挪威的森林        [日] 村上春树  林少华     上海译文出版社    18.80元   8.0  (322683人评价)
# 3      麦田里的守望者  [美国] J. D. 塞林格  孙仲旭       译林出版社    28.00元   8.1   (65185人评价)
# 4   那些回不去的年少时光                   桐华     江苏文艺出版社    23.80元   8.4   (50640人评价)
# ..         ...                   ...         ...      ...   ...          ...
# 84  陪安东尼度过漫长岁月                  安东尼     长江文艺出版社    18.00元   8.3   (64622人评价)
# 85      像少年啦飞驰                   韩寒       作家出版社    16.00元   7.3   (40419人评价)
# 86          西决                   笛安     长江文艺出版社    22.80元   7.9   (56442人评价)
# 87        血色浪漫                   都梁     人民文学出版社    40.00元   8.9    (3296人评价)
# 88        狼的诱惑              可爱淘  黄黉     世界知识出版社     20.0元   6.8   (14946人评价)
#
#     aut_num
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 84        1
# 85        1
# 86        1
# 87        1
# 88        1
#
# [89 rows x 7 columns]

# %%
df_author = author[ ['作者','aut_num'] ].groupby(['作者']).sum()#按照作者进行分组，得到不同作者的图书数量
df_auth=df_author.sort_values(by=['aut_num'],ascending=False)
df_auth
# Out:
#                   aut_num
# 作者
# 郭敬明                     5
# 顾漫                      5
# 韩寒                      5
# [日] 村上春树  林少华           4
# 巫哲                      3
# ...                   ...
# 安妮宝贝                    1
# 安妮宝贝 原著、鬼鬼 改编绘画         1
# 安德烈·艾席蒙  权景             1
# 岩井俊二  穆晓芳               1
# （日）三岛由纪夫  唐月梅           1
#
# [66 rows x 1 columns]

# %%
df.dropna()#去掉空值
df_info=df_s.iloc[0:20]#评分前20的书籍信息
mask = df_info[(True^df['豆瓣评分'].isin([0]))]
mask['Mask'] = 1#添加计数器
mask
# Out:
# c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#            书名                  作者           出版社         售价  豆瓣评分         评论数量  \
# 18       少年凯歌                陈凯歌       人民文学出版社      10.00元   9.2    (5724人评价)
# 64    吞噬时间的恋人                王宇昆       天津人民出版社      42.00元   9.1      (23人评价)
# 26       绿毛水怪                王小波     北京十月文艺出版社      39.00元   9.1    (5834人评价)
# 17       怦然心动    文德琳·范·德拉安南  陈常歌      百花洲文艺出版社      42.80元   9.1    (3865人评价)
# 16      平凡的世界                 路遥     北京十月文艺出版社      99.00元   9.1   (17531人评价)
# 8        强风吹拂  三浦紫苑  林佩瑾、李建铨、杨正敏     广西师范大学出版社      39.00元   9.0   (12826人评价)
# 45         情书          岩井俊二  穆晓芳        南海出版公司      45.00元   8.9    (5098人评价)
# 87       血色浪漫                 都梁       人民文学出版社      40.00元   8.9    (3296人评价)
# 50         潮骚      [日] 三岛由纪夫  张舟     北京十月文艺出版社         45元   8.8    (1956人评价)
# 65       白日事故          高台樹色  留守番            ***   NTD 780元   8.8    (1379人评价)
# 9        夏日终曲   [美] 安德烈·艾席蒙  吴妍蓉    外语教学与研究出版社      39.90元   8.8   (16509人评价)
# 15      雨季不再来                 三毛     北京十月文艺出版社      28.00元   8.7   (42955人评价)
# 7       最好的我们               八月长安       湖南文艺出版社         55元   8.7   (59187人评价)
# 34        小先生                咬春饼         青岛出版社      65.00元   8.6     (930人评价)
# 32  请以你的名字呼唤我        安德烈·艾席蒙  权景      中国友谊出版公司      29.80元   8.6    (9939人评价)
# 0          撒野                 巫哲      北京联合出版公司      45.00元   8.6   (29981人评价)
# 6          情书      [日] 岩井俊二  穆晓芳       天津人民出版社      18.00元   8.6   (89576人评价)
# 11      挪威的森林       [日]村上春树  林少华       上海译文出版社      38.00元   8.6    (8971人评价)
# 27      横道世之介      [日] 吉田修一  林雅惠       上海人民出版社      55.00元   8.5    (3669人评价)
# 5       挪威的森林      [日] 村上春树  林少华       上海译文出版社      23.00元   8.5  (108127人评价)
#
#     Mask
# 18     1
# 64     1
# 26     1
# 17     1
# 16     1
# 8      1
# 45     1
# 87     1
# 50     1
# 65     1
# 9      1
# 15     1
# 7      1
# 34     1
# 32     1
# 0      1
# 6      1
# 11     1
# 27     1
# 5      1

# %%
df_mask = mask[ ['豆瓣评分','Mask'] ].groupby(['豆瓣评分']).sum()#按照级别进行分组，得到不同级别景区数量
df_mask
# Out:
#       Mask
# 豆瓣评分
# 8.5      2
# 8.6      5
# 8.7      2
# 8.8      3
# 8.9      2
# 9.0      1
# 9.1      4
# 9.2      1

# %%
import matplotlib.pyplot as plt  #豆瓣评分前20的书籍中各个评分所占比例
df_mask.plot.pie(subplots = True, figsize = (6,6))#画饼图
plt.show()

# %%
df_infoList = df_info.reset_index()
df_infoList['评分排名'] = df_infoList.index + 1
df_infoList
# Out:
#     index         书名                  作者           出版社         售价  豆瓣评分  \
# 0      18       少年凯歌                陈凯歌       人民文学出版社      10.00元   9.2
# 1      64    吞噬时间的恋人                王宇昆       天津人民出版社      42.00元   9.1
# 2      26       绿毛水怪                王小波     北京十月文艺出版社      39.00元   9.1
# 3      17       怦然心动    文德琳·范·德拉安南  陈常歌      百花洲文艺出版社      42.80元   9.1
# 4      16      平凡的世界                 路遥     北京十月文艺出版社      99.00元   9.1
# 5       8       强风吹拂  三浦紫苑  林佩瑾、李建铨、杨正敏     广西师范大学出版社      39.00元   9.0
# 6      45         情书          岩井俊二  穆晓芳        南海出版公司      45.00元   8.9
# 7      87       血色浪漫                 都梁       人民文学出版社      40.00元   8.9
# 8      50         潮骚      [日] 三岛由纪夫  张舟     北京十月文艺出版社         45元   8.8
# 9      65       白日事故          高台樹色  留守番            ***   NTD 780元   8.8
# 10      9       夏日终曲   [美] 安德烈·艾席蒙  吴妍蓉    外语教学与研究出版社      39.90元   8.8
# 11     15      雨季不再来                 三毛     北京十月文艺出版社      28.00元   8.7
# 12      7      最好的我们               八月长安       湖南文艺出版社         55元   8.7
# 13     34        小先生                咬春饼         青岛出版社      65.00元   8.6
# 14     32  请以你的名字呼唤我        安德烈·艾席蒙  权景      中国友谊出版公司      29.80元   8.6
# 15      0         撒野                 巫哲      北京联合出版公司      45.00元   8.6
# 16      6         情书      [日] 岩井俊二  穆晓芳       天津人民出版社      18.00元   8.6
# 17     11      挪威的森林       [日]村上春树  林少华       上海译文出版社      38.00元   8.6
# 18     27      横道世之介      [日] 吉田修一  林雅惠       上海人民出版社      55.00元   8.5
# 19      5      挪威的森林      [日] 村上春树  林少华       上海译文出版社      23.00元   8.5
#
#            评论数量  评分排名
# 0     (5724人评价)     1
# 1       (23人评价)     2
# 2     (5834人评价)     3
# 3     (3865人评价)     4
# 4    (17531人评价)     5
# 5    (12826人评价)     6
# 6     (5098人评价)     7
# 7     (3296人评价)     8
# 8     (1956人评价)     9
# 9     (1379人评价)    10
# 10   (16509人评价)    11
# 11   (42955人评价)    12
# 12   (59187人评价)    13
# 13     (930人评价)    14
# 14    (9939人评价)    15
# 15   (29981人评价)    16
# 16   (89576人评价)    17
# 17    (8971人评价)    18
# 18    (3669人评价)    19
# 19  (108127人评价)    20

# %%
df_auinfo=df_auth.iloc[0:5]
df_auinfo
# Out:
#                 aut_num
# 作者
# 郭敬明                   5
# 顾漫                    5
# 韩寒                    5
# [日] 村上春树  林少华         4
# 巫哲                    3

# %%
plt.rcParams['font.sans-serif'] = ['SimHei'] #显示中文汉字
df_auinfo.plot(kind = 'barh')#青春小说书籍中 收录最多的前五位作者的柱形图
plt.show()

# %%
df_maskF=df_ss.iloc[0:10]
df_Firstm=df_maskF[['书名','豆瓣评分']]
df_Firstm
# Out:
#          书名  豆瓣评分
# 18     少年凯歌   9.2
# 64  吞噬时间的恋人   9.1
# 26     绿毛水怪   9.1
# 17     怦然心动   9.1
# 16    平凡的世界   9.1
# 8      强风吹拂   9.0
# 45       情书   8.9
# 87     血色浪漫   8.9
# 50       潮骚   8.8
# 65     白日事故   8.8

# %%
plt.rcParams['font.sans-serif'] = ['SimHei'] #显示中文汉字
df_Firstm.plot(kind = 'hist')#青春小说书籍中 评分最高的十本小说的豆瓣评分 分布频率柱形图
plt.show()
